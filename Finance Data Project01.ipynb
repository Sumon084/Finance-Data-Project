# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

# %%
BAC=data.DataReader('BAC',start='2006, 1, 1', end='2016, 1, 1', data_source='yahoo')
BAC.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.777512
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.418789
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.461823
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.411617
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.433136

# %%
C=data.DataReader('C',start='2006, 1, 1', end='2016, 1, 1',data_source='yahoo')
C.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  1537600.0
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  1870960.0
# 2006-01-05  487.799988  484.000000  484.399994  486.200012  1143160.0
# 2006-01-06  489.000000  482.000000  488.799988  486.200012  1370210.0
# 2006-01-09  487.399994  483.000000  486.000000  483.899994  1680740.0
#
#              Adj Close
# Date
# 2006-01-03  365.387451
# 2006-01-04  358.641693
# 2006-01-05  360.420837
# 2006-01-06  360.420837
# 2006-01-09  358.715820

# %%
GS=data.DataReader('GS',start='2006, 1, 1', end='2016, 1, 1',data_source='yahoo')
GS.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2006-01-03  129.440002  124.230003  126.699997  128.869995  6188700.0
# 2006-01-04  128.910004  126.379997  127.349998  127.089996  4861600.0
# 2006-01-05  127.320000  125.610001  126.000000  127.040001  3717400.0
# 2006-01-06  129.250000  127.290001  127.290001  128.839996  4319600.0
# 2006-01-09  130.619995  128.000000  128.500000  130.389999  4723500.0
#
#              Adj Close
# Date
# 2006-01-03  103.255325
# 2006-01-04  101.829147
# 2006-01-05  101.789070
# 2006-01-06  103.231262
# 2006-01-09  104.473221

# %%
JPM=data.DataReader('JPM',start='2006, 1, 1', end='2016, 1, 1',data_source='yahoo')
JPM.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  40.360001  39.299999  39.830002  40.189999  12838600.0  26.151632
# 2006-01-04  40.139999  39.419998  39.779999  39.619999  13491500.0  26.000689
# 2006-01-05  39.810001  39.500000  39.610001  39.740002   8109400.0  26.079445
# 2006-01-06  40.240002  39.549999  39.919998  40.020000   7966900.0  26.263189
# 2006-01-09  40.720001  39.880001  39.880001  40.669998  16575200.0  26.689756

# %%
MS=data.DataReader('MS',start='2006, 1, 1', end='2016, 1, 1',data_source='yahoo')
MS.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-01-03  58.490002  56.740002  57.169998  58.310001  5377000.0  35.864323
# 2006-01-04  59.279999  58.349998  58.700001  58.349998  7977800.0  35.888943
# 2006-01-05  58.590000  58.020000  58.549999  58.509998  5778000.0  35.987350
# 2006-01-06  58.849998  58.049999  58.770000  58.570000  6889800.0  36.024258
# 2006-01-09  59.290001  58.619999  58.630001  59.189999  4144500.0  36.405567

# %%
WFC=data.DataReader('WFC',start='2006, 1, 1', end='2016, 1, 1',data_source='yahoo')
WFC.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  31.975000  31.195000  31.600000  31.900000  11016400.0  20.353489
# 2006-01-04  31.820000  31.365000  31.799999  31.530001  10870000.0  20.117411
# 2006-01-05  31.555000  31.309999  31.500000  31.495001  10158000.0  20.095079
# 2006-01-06  31.775000  31.385000  31.580000  31.680000   8403800.0  20.213116
# 2006-01-09  31.825001  31.555000  31.674999  31.674999   5619600.0  20.209919

# %%
tickers = ['BAC', 'C','GS','JPM','MS','WFC']
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
bank_stocks = pd.concat([BAC,C,GS,JPM,MS,WFC], axis=1, keys=tickers)
bank_stocks.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.777512
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.418789
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.461823
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.411617
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.433136
#
#                      C                                      ...         MS  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  57.169998
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  58.700001
# ...

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   33.777512  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   33.418789  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   33.461823  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %%
bank_stocks['BAC']['Close'].max()
# Out:
# 54.900001525878906

# %%
for tick in tickers:
    print(tick, bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.900001525878906
# C 564.0999755859375
# GS 247.9199981689453
# JPM 70.08000183105469
# MS 89.30000305175781
# WFC 58.52000045776367

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick +' Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %%
sns.pairplot(returns)

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WFC Return    0.030238
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'], color='green', bins=50)
# Out:
# C:\Users\HP\anaconda3\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MS Return', ylabel='Density'>

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'], color='red',bins=50)
# Out:
# C:\Users\HP\anaconda3\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='C Return', ylabel='Density'>

# %%
# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick, figsize=(12,4))
plt.legend()

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').iplot()
# Out:
# <div>                            <div id="4b77a7fb-8a28-4d58-b013-eebcff5bda7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
plt.figure(figsize=(12,4))
BAC['Close'].loc['2008-01-01':'2008-12-31'].rolling(window=30).mean().plot(label='30 Day Moving Average')
BAC['Close'].loc['2008-01-01':'2008-12-31'].plot(label= 'BAC Close')
plt.legend()

# %%
stock_close_price = bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr()
sns.heatmap(stock_close_price)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
sns.heatmap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot= True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
sns.clustermap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot= True)

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
stock_close_price = bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr()
stock_close_price
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS       WFC
# Bank Ticker
# BAC          1.000000  0.971516  0.550898  0.103874  0.944218  0.008542
# C            0.971516  1.000000  0.434123  0.003515  0.933609 -0.068536
# GS           0.550898  0.434123  1.000000  0.685286  0.683792  0.499897
# JPM          0.103874  0.003515  0.685286  1.000000  0.250427  0.940269
# MS           0.944218  0.933609  0.683792  0.250427  1.000000  0.131835
# WFC          0.008542 -0.068536  0.499897  0.940269  0.131835  1.000000

# %%
stock_close_price.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="6139707b-dac3-4b9c-ace2-ecb436f82a1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
BAC[['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# <div>                            <div id="46b51164-798c-4a0d-be36-6b77bb759cb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
MS['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma',periods=[13,21,55],title='Simple Moving Averages')
# Out:
# <div>                            <div id="7fbca797-bbd8-4dab-82f0-5ce4deb8c25d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
BAC['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# <div>                            <div id="b94bab25-445f-4313-bde9-43d406c16fa9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
